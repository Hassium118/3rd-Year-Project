# %% [markdown]
# # PCB Binary Classifier — MobileNetV2
# Uses transfer learning with MobileNetV2 (alpha=0.35) for PCB / not-PCB detection.

# %% [markdown]
# ## 1. Imports

# %%
import os
import shutil
import random
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import keras
from keras import layers
from tensorflow import data as tf_data
from tensorflow import lite

print("TF version:", tf.__version__)
print("Keras version:", keras.__version__)
# Out:
# 2026-03-01 15:32:10.279977: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1772379130.449152      55 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1772379130.494436      55 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1772379130.869591      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1772379130.869633      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1772379130.869636      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1772379130.869638      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# TF version: 2.19.0
# Keras version: 3.10.0

# %% [markdown]
# ## 2. Config

# %%
INPUT_SIZE  = 96        # MobileNetV2 minimum is 96x96
BATCH_SIZE  = 32
EPOCHS_TOP  = 10       
EPOCHS_FINE = 10       
CLASS_NUM   = 2
LABELS      = ["not_pcb", "pcb"]  

TRAIN_DIR    = "/kaggle/working/balanced/train"
VALIDATE_DIR = "/kaggle/working/balanced/validate"
TEST_DIR     = "/kaggle/working/balanced/test"

# %% [markdown]
# ## 3. Rebalance Dataset

# %%
val_not_pcb = "/kaggle/input/datasets/hassenalrubei/pcbvnotpcb/dataset/validate/not_pcb"
files = os.listdir(val_not_pcb)
random.seed(42)
keep = set(random.sample(files, 51))  # match PCB count

for split in ["train", "validate", "test"]:
    for cls in ["pcb", "not_pcb"]:
        src = f"/kaggle/input/datasets/hassenalrubei/pcbvnotpcb/dataset/{split}/{cls}"
        dst = f"/kaggle/working/balanced/{split}/{cls}"
        os.makedirs(dst, exist_ok=True)
        for f in os.listdir(src):
            if split == "validate" and cls == "not_pcb" and f not in keep:
                continue
            shutil.copy(os.path.join(src, f), dst)

for split in ["train", "validate", "test"]:
    path = f"/kaggle/working/balanced/{split}"
    counts = {c: len(os.listdir(os.path.join(path, c))) for c in os.listdir(path)}
    print(f"{split}: {counts}")
# Out:
# train: {'pcb': 847, 'not_pcb': 1116}
# validate: {'pcb': 51, 'not_pcb': 51}
# test: {'pcb': 102, 'not_pcb': 240}

# %% [markdown]
# ## 4. Data Augmentation & Loading
#
# Normalisation uses `img / 127.5 - 1` to map pixels to `[-1, 1]`, which is what MobileNetV2 expects.

# %%
data_augmentation_layers = [
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.1),
    layers.RandomZoom(0.1),
    layers.RandomContrast(0.1),
]

def data_augmentation(images):
    for layer in data_augmentation_layers:
        images = layer(images)
    return images

def load_ds(path, augment=False, shuffle=False):
    ds = keras.utils.image_dataset_from_directory(
    path,
    validation_split=None,
    seed=1337,
    shuffle=shuffle,
    image_size=(INPUT_SIZE, INPUT_SIZE),
    batch_size=BATCH_SIZE,
    label_mode="categorical",
    class_names=LABELS,
    )
    if augment:
        ds = ds.map(
            lambda img, label: (data_augmentation(img) / 127.5 - 1, label),
            num_parallel_calls=tf_data.AUTOTUNE,
        )
    else:
        ds = ds.map(
            lambda img, label: (img / 127.5 - 1, label),
            num_parallel_calls=tf_data.AUTOTUNE,
        )
    return ds.prefetch(tf_data.AUTOTUNE)

train_ds    = load_ds(TRAIN_DIR,    augment=True,  shuffle=True)
validate_ds = load_ds(VALIDATE_DIR, augment=False, shuffle=False)
test_ds     = load_ds(TEST_DIR,     augment=False, shuffle=False)

print("Classes:", LABELS)
# Out:
# Found 1963 files belonging to 2 classes.
# Found 102 files belonging to 2 classes.
# Found 342 files belonging to 2 classes.
# Classes: ['not_pcb', 'pcb']

# %% [markdown]
# ## 5. Build Model

# %%
def build_model():
    input_shape = (INPUT_SIZE, INPUT_SIZE, 3)
    inputs = layers.Input(shape=input_shape)

    base = keras.applications.MobileNetV2(
        alpha=0.5,
        include_top=False,
        input_shape=input_shape,
        input_tensor=inputs,
        weights="imagenet",
    )
    base.trainable = False  # freeze pretrained weights initially

    x = layers.GlobalAveragePooling2D(name="avg_pool")(base.output)
    x = layers.BatchNormalization()(x)
    x = layers.Dropout(0.2)(x)
    outputs = layers.Dense(CLASS_NUM, activation="softmax")(x)

    return keras.Model(inputs, outputs)

model = build_model()
model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_0.5_96_no_top.h5
# 3201480/3201480 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_2       │ (None, 96, 96, 3) │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Conv1 (Conv2D)      │ (None, 48, 48,    │        432 │ input_layer_2[0]… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bn_Conv1            │ (None, 48, 48,    │         64 │ Conv1[0][0]       │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Conv1_relu (ReLU)   │ (None, 48, 48,    │          0 │ bn_Conv1[0][0]    │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_dept… │ (None, 48, 48,    │        144 │ Conv1_relu[0][0]  │
# │ (DepthwiseConv2D)   │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_dept… │ (None, 48, 48,    │         64 │ expanded_conv_de… │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_dept… │ (None, 48, 48,    │          0 │ expanded_conv_de… │
# │ (ReLU)              │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_proj… │ (None, 48, 48, 8) │        128 │ expanded_conv_de… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_proj… │ (None, 48, 48, 8) │         32 │ expanded_conv_pr… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_expand      │ (None, 48, 48,    │        384 │ expanded_conv_pr… │
# │ (Conv2D)            │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_expand_BN   │ (None, 48, 48,    │        192 │ block_1_expand[0… │
# │ (BatchNormalizatio… │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_expand_relu │ (None, 48, 48,    │          0 │ block_1_expand_B… │
# │ (ReLU)              │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_pad         │ (None, 49, 49,    │          0 │ block_1_expand_r… │
# │ (ZeroPadding2D)     │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_depthwise   │ (None, 24, 24,    │        432 │ block_1_pad[0][0] │
# │ (DepthwiseConv2D)   │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_depthwise_… │ (None, 24, 24,    │        192 │ block_1_depthwis… │
# │ (BatchNormalizatio… │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_depthwise_… │ (None, 24, 24,    │          0 │ block_1_depthwis… │
# │ (ReLU)              │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_project     │ (None, 24, 24,    │        768 │ block_1_depthwis… │
# │ (Conv2D)            │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_project_BN  │ (None, 24, 24,    │         64 │ block_1_project[… │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_expand      │ (None, 24, 24,    │      1,536 │ block_1_project_… │
# │ (Conv2D)            │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_expand_BN   │ (None, 24, 24,    │        384 │ block_2_expand[0… │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_expand_relu │ (None, 24, 24,    │          0 │ block_2_expand_B… │
# │ (ReLU)              │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_depthwise   │ (None, 24, 24,    │        864 │ block_2_expand_r… │
# │ (DepthwiseConv2D)   │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_depthwise_… │ (None, 24, 24,    │        384 │ block_2_depthwis… │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_depthwise_… │ (None, 24, 24,    │          0 │ block_2_depthwis… │
# │ (ReLU)              │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_project     │ (None, 24, 24,    │      1,536 │ block_2_depthwis… │
# │ (Conv2D)            │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_project_BN  │ (None, 24, 24,    │         64 │ block_2_project[… │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_add (Add)   │ (None, 24, 24,    │          0 │ block_1_project_… │
# │                     │ 16)               │            │ block_2_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_expand      │ (None, 24, 24,    │      1,536 │ block_2_add[0][0] │
# │ (Conv2D)            │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_expand_BN   │ (None, 24, 24,    │        384 │ block_3_expand[0… │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_expand_relu │ (None, 24, 24,    │          0 │ block_3_expand_B… │
# │ (ReLU)              │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_pad         │ (None, 25, 25,    │          0 │ block_3_expand_r… │
# │ (ZeroPadding2D)     │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_depthwise   │ (None, 12, 12,    │        864 │ block_3_pad[0][0] │
# │ (DepthwiseConv2D)   │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_depthwise_… │ (None, 12, 12,    │        384 │ block_3_depthwis… │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_depthwise_… │ (None, 12, 12,    │          0 │ block_3_depthwis… │
# │ (ReLU)              │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_project     │ (None, 12, 12,    │      1,536 │ block_3_depthwis… │
# │ (Conv2D)            │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_project_BN  │ (None, 12, 12,    │         64 │ block_3_project[… │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_expand      │ (None, 12, 12,    │      1,536 │ block_3_project_… │
# │ (Conv2D)            │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_expand_BN   │ (None, 12, 12,    │        384 │ block_4_expand[0… │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_expand_relu │ (None, 12, 12,    │          0 │ block_4_expand_B… │
# │ (ReLU)              │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_depthwise   │ (None, 12, 12,    │        864 │ block_4_expand_r… │
# │ (DepthwiseConv2D)   │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_depthwise_… │ (None, 12, 12,    │        384 │ block_4_depthwis… │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_depthwise_… │ (None, 12, 12,    │          0 │ block_4_depthwis… │
# │ (ReLU)              │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_project     │ (None, 12, 12,    │      1,536 │ block_4_depthwis… │
# │ (Conv2D)            │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_project_BN  │ (None, 12, 12,    │         64 │ block_4_project[… │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_add (Add)   │ (None, 12, 12,    │          0 │ block_3_project_… │
# │                     │ 16)               │            │ block_4_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_expand      │ (None, 12, 12,    │      1,536 │ block_4_add[0][0] │
# │ (Conv2D)            │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_expand_BN   │ (None, 12, 12,    │        384 │ block_5_expand[0… │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_expand_relu │ (None, 12, 12,    │          0 │ block_5_expand_B… │
# │ (ReLU)              │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_depthwise   │ (None, 12, 12,    │        864 │ block_5_expand_r… │
# │ (DepthwiseConv2D)   │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_depthwise_… │ (None, 12, 12,    │        384 │ block_5_depthwis… │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_depthwise_… │ (None, 12, 12,    │          0 │ block_5_depthwis… │
# │ (ReLU)              │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_project     │ (None, 12, 12,    │      1,536 │ block_5_depthwis… │
# │ (Conv2D)            │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_project_BN  │ (None, 12, 12,    │         64 │ block_5_project[… │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_add (Add)   │ (None, 12, 12,    │          0 │ block_4_add[0][0… │
# │                     │ 16)               │            │ block_5_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_expand      │ (None, 12, 12,    │      1,536 │ block_5_add[0][0] │
# │ (Conv2D)            │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_expand_BN   │ (None, 12, 12,    │        384 │ block_6_expand[0… │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_expand_relu │ (None, 12, 12,    │          0 │ block_6_expand_B… │
# │ (ReLU)              │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_pad         │ (None, 13, 13,    │          0 │ block_6_expand_r… │
# │ (ZeroPadding2D)     │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_depthwise   │ (None, 6, 6, 96)  │        864 │ block_6_pad[0][0] │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_depthwise_… │ (None, 6, 6, 96)  │        384 │ block_6_depthwis… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_depthwise_… │ (None, 6, 6, 96)  │          0 │ block_6_depthwis… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_project     │ (None, 6, 6, 32)  │      3,072 │ block_6_depthwis… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_project_BN  │ (None, 6, 6, 32)  │        128 │ block_6_project[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_expand      │ (None, 6, 6, 192) │      6,144 │ block_6_project_… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_expand_BN   │ (None, 6, 6, 192) │        768 │ block_7_expand[0… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_expand_relu │ (None, 6, 6, 192) │          0 │ block_7_expand_B… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_depthwise   │ (None, 6, 6, 192) │      1,728 │ block_7_expand_r… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_depthwise_… │ (None, 6, 6, 192) │        768 │ block_7_depthwis… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_depthwise_… │ (None, 6, 6, 192) │          0 │ block_7_depthwis… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_project     │ (None, 6, 6, 32)  │      6,144 │ block_7_depthwis… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_project_BN  │ (None, 6, 6, 32)  │        128 │ block_7_project[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_add (Add)   │ (None, 6, 6, 32)  │          0 │ block_6_project_… │
# │                     │                   │            │ block_7_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_expand      │ (None, 6, 6, 192) │      6,144 │ block_7_add[0][0] │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_expand_BN   │ (None, 6, 6, 192) │        768 │ block_8_expand[0… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_expand_relu │ (None, 6, 6, 192) │          0 │ block_8_expand_B… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_depthwise   │ (None, 6, 6, 192) │      1,728 │ block_8_expand_r… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_depthwise_… │ (None, 6, 6, 192) │        768 │ block_8_depthwis… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_depthwise_… │ (None, 6, 6, 192) │          0 │ block_8_depthwis… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_project     │ (None, 6, 6, 32)  │      6,144 │ block_8_depthwis… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_project_BN  │ (None, 6, 6, 32)  │        128 │ block_8_project[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_add (Add)   │ (None, 6, 6, 32)  │          0 │ block_7_add[0][0… │
# │                     │                   │            │ block_8_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_expand      │ (None, 6, 6, 192) │      6,144 │ block_8_add[0][0] │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_expand_BN   │ (None, 6, 6, 192) │        768 │ block_9_expand[0… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_expand_relu │ (None, 6, 6, 192) │          0 │ block_9_expand_B… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_depthwise   │ (None, 6, 6, 192) │      1,728 │ block_9_expand_r… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_depthwise_… │ (None, 6, 6, 192) │        768 │ block_9_depthwis… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_depthwise_… │ (None, 6, 6, 192) │          0 │ block_9_depthwis… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_project     │ (None, 6, 6, 32)  │      6,144 │ block_9_depthwis… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_project_BN  │ (None, 6, 6, 32)  │        128 │ block_9_project[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_add (Add)   │ (None, 6, 6, 32)  │          0 │ block_8_add[0][0… │
# │                     │                   │            │ block_9_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_expand     │ (None, 6, 6, 192) │      6,144 │ block_9_add[0][0] │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_expand_BN  │ (None, 6, 6, 192) │        768 │ block_10_expand[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_expand_re… │ (None, 6, 6, 192) │          0 │ block_10_expand_… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_depthwise  │ (None, 6, 6, 192) │      1,728 │ block_10_expand_… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_depthwise… │ (None, 6, 6, 192) │        768 │ block_10_depthwi… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_depthwise… │ (None, 6, 6, 192) │          0 │ block_10_depthwi… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_project    │ (None, 6, 6, 48)  │      9,216 │ block_10_depthwi… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_project_BN │ (None, 6, 6, 48)  │        192 │ block_10_project… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_expand     │ (None, 6, 6, 288) │     13,824 │ block_10_project… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_expand_BN  │ (None, 6, 6, 288) │      1,152 │ block_11_expand[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_expand_re… │ (None, 6, 6, 288) │          0 │ block_11_expand_… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_depthwise  │ (None, 6, 6, 288) │      2,592 │ block_11_expand_… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_depthwise… │ (None, 6, 6, 288) │      1,152 │ block_11_depthwi… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_depthwise… │ (None, 6, 6, 288) │          0 │ block_11_depthwi… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_project    │ (None, 6, 6, 48)  │     13,824 │ block_11_depthwi… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_project_BN │ (None, 6, 6, 48)  │        192 │ block_11_project… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_add (Add)  │ (None, 6, 6, 48)  │          0 │ block_10_project… │
# │                     │                   │            │ block_11_project… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_expand     │ (None, 6, 6, 288) │     13,824 │ block_11_add[0][… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_expand_BN  │ (None, 6, 6, 288) │      1,152 │ block_12_expand[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_expand_re… │ (None, 6, 6, 288) │          0 │ block_12_expand_… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_depthwise  │ (None, 6, 6, 288) │      2,592 │ block_12_expand_… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_depthwise… │ (None, 6, 6, 288) │      1,152 │ block_12_depthwi… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_depthwise… │ (None, 6, 6, 288) │          0 │ block_12_depthwi… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_project    │ (None, 6, 6, 48)  │     13,824 │ block_12_depthwi… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_project_BN │ (None, 6, 6, 48)  │        192 │ block_12_project… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_add (Add)  │ (None, 6, 6, 48)  │          0 │ block_11_add[0][… │
# │                     │                   │            │ block_12_project… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_expand     │ (None, 6, 6, 288) │     13,824 │ block_12_add[0][… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_expand_BN  │ (None, 6, 6, 288) │      1,152 │ block_13_expand[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_expand_re… │ (None, 6, 6, 288) │          0 │ block_13_expand_… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_pad        │ (None, 7, 7, 288) │          0 │ block_13_expand_… │
# │ (ZeroPadding2D)     │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_depthwise  │ (None, 3, 3, 288) │      2,592 │ block_13_pad[0][… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_depthwise… │ (None, 3, 3, 288) │      1,152 │ block_13_depthwi… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_depthwise… │ (None, 3, 3, 288) │          0 │ block_13_depthwi… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_project    │ (None, 3, 3, 80)  │     23,040 │ block_13_depthwi… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_project_BN │ (None, 3, 3, 80)  │        320 │ block_13_project… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_expand     │ (None, 3, 3, 480) │     38,400 │ block_13_project… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_expand_BN  │ (None, 3, 3, 480) │      1,920 │ block_14_expand[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_expand_re… │ (None, 3, 3, 480) │          0 │ block_14_expand_… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_depthwise  │ (None, 3, 3, 480) │      4,320 │ block_14_expand_… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_depthwise… │ (None, 3, 3, 480) │      1,920 │ block_14_depthwi… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_depthwise… │ (None, 3, 3, 480) │          0 │ block_14_depthwi… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_project    │ (None, 3, 3, 80)  │     38,400 │ block_14_depthwi… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_project_BN │ (None, 3, 3, 80)  │        320 │ block_14_project… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_add (Add)  │ (None, 3, 3, 80)  │          0 │ block_13_project… │
# │                     │                   │            │ block_14_project… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_expand     │ (None, 3, 3, 480) │     38,400 │ block_14_add[0][… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_expand_BN  │ (None, 3, 3, 480) │      1,920 │ block_15_expand[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_expand_re… │ (None, 3, 3, 480) │          0 │ block_15_expand_… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_depthwise  │ (None, 3, 3, 480) │      4,320 │ block_15_expand_… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_depthwise… │ (None, 3, 3, 480) │      1,920 │ block_15_depthwi… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_depthwise… │ (None, 3, 3, 480) │          0 │ block_15_depthwi… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_project    │ (None, 3, 3, 80)  │     38,400 │ block_15_depthwi… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_project_BN │ (None, 3, 3, 80)  │        320 │ block_15_project… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_add (Add)  │ (None, 3, 3, 80)  │          0 │ block_14_add[0][… │
# │                     │                   │            │ block_15_project… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_expand     │ (None, 3, 3, 480) │     38,400 │ block_15_add[0][… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_expand_BN  │ (None, 3, 3, 480) │      1,920 │ block_16_expand[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_expand_re… │ (None, 3, 3, 480) │          0 │ block_16_expand_… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_depthwise  │ (None, 3, 3, 480) │      4,320 │ block_16_expand_… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_depthwise… │ (None, 3, 3, 480) │      1,920 │ block_16_depthwi… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_depthwise… │ (None, 3, 3, 480) │          0 │ block_16_depthwi… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_project    │ (None, 3, 3, 160) │     76,800 │ block_16_depthwi… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_project_BN │ (None, 3, 3, 160) │        640 │ block_16_project… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Conv_1 (Conv2D)     │ (None, 3, 3,      │    204,800 │ block_16_project… │
# │                     │ 1280)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Conv_1_bn           │ (None, 3, 3,      │      5,120 │ Conv_1[0][0]      │
# │ (BatchNormalizatio… │ 1280)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ out_relu (ReLU)     │ (None, 3, 3,      │          0 │ Conv_1_bn[0][0]   │
# │                     │ 1280)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ avg_pool            │ (None, 1280)      │          0 │ out_relu[0][0]    │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 1280)      │      5,120 │ avg_pool[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 1280)      │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 2)         │      2,562 │ dropout[0][0]     │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 713,906 (2.72 MB)
#  Trainable params: 5,122 (20.01 KB)
#  Non-trainable params: 708,784 (2.70 MB)

# %% [markdown]
# ## 6. Phase 1 — Train Classifier Head

# %%
model.compile(
    optimizer=keras.optimizers.Adam(1e-3),
    loss="categorical_crossentropy",
    metrics=["accuracy"],
)

callbacks = [
    keras.callbacks.EarlyStopping(patience=5, restore_best_weights=True),
    keras.callbacks.ReduceLROnPlateau(factor=0.5, patience=3, verbose=1),
]

history_top = model.fit(
    train_ds,
    validation_data=validate_ds,
    epochs=EPOCHS_TOP,
    callbacks=callbacks,
)
# Out:
# Epoch 1/10
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1772291118.289442     121 service.cc:152] XLA service 0x796a3c002c30 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1772291118.289493     121 service.cc:160]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# I0000 00:00:1772291119.306626     121 cuda_dnn.cc:529] Loaded cuDNN version 91002
# I0000 00:00:1772291124.042622     121 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 25s 222ms/step - accuracy: 0.7318 - loss: 0.5902 - val_accuracy: 0.9510 - val_loss: 0.1540 - learning_rate: 0.0010
# Epoch 2/10
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - accuracy: 0.9130 - loss: 0.2260 - val_accuracy: 0.9314 - val_loss: 0.1435 - learning_rate: 0.0010
# Epoch 3/10
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - accuracy: 0.9323 - loss: 0.1676 - val_accuracy: 0.9412 - val_loss: 0.1413 - learning_rate: 0.0010
# Epoch 4/10
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 0.9516 - loss: 0.1357 - val_accuracy: 0.9510 - val_loss: 0.1461 - learning_rate: 0.0010
# Epoch 5/10
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.9444 - loss: 0.1363 - val_accuracy: 0.9510 - val_loss: 0.1546 - learning_rate: 0.0010
# Epoch 6/10
# 59/62 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9477 - loss: 0.1343
# Epoch 6: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 0.9478 - loss: 0.1336 - val_accuracy: 0.9608 - val_loss: 0.1424 - learning_rate: 0.0010
# Epoch 7/10
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.9431 - loss: 0.1563 - val_accuracy: 0.9608 - val_loss: 0.1382 - learning_rate: 5.0000e-04
# Epoch 8/10
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.9592 - loss: 0.1095 - val_accuracy: 0.9608 - val_loss: 0.1421 - learning_rate: 5.0000e-04
# Epoch 9/10
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 0.9584 - loss: 0.0962 - val_accuracy: 0.9608 - val_loss: 0.1571 - learning_rate: 5.0000e-04
# Epoch 10/10
# 59/62 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9643 - loss: 0.0976
# Epoch 10: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 0.9644 - loss: 0.0971 - val_accuracy: 0.9608 - val_loss: 0.1535 - learning_rate: 5.0000e-04

# %% [markdown]
# ## 8. Evaluate on Test Set

# %%
loss, acc = model.evaluate(test_ds)
print(f"Test accuracy: {acc:.2%}  |  Test loss: {loss:.4f}")
# Out:
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 381ms/step - accuracy: 0.9776 - loss: 0.0496
# Test accuracy: 94.74%  |  Test loss: 0.1122

# %% [markdown]
# ## 9. Training History

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 4))

axes[0].plot(history_top.history["accuracy"],     label="Train")
axes[0].plot(history_top.history["val_accuracy"], label="Val")
axes[0].set_title("Accuracy")
axes[0].legend()

axes[1].plot(history_top.history["loss"],     label="Train")
axes[1].plot(history_top.history["val_loss"], label="Val")
axes[1].set_title("Loss")
axes[1].legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 10. Convert to INT8 TFLite

# %%
def representative_dataset():
    for images, _ in train_ds.take(100):
        for img in images:
            yield [tf.expand_dims(img, 0)]

converter = lite.TFLiteConverter.from_keras_model(model)
converter._experimental_disable_per_channel_quantization_for_dense_layers = True
converter.optimizations = [lite.Optimize.DEFAULT]
converter.representative_dataset = representative_dataset
converter.target_spec.supported_ops = [lite.OpsSet.TFLITE_BUILTINS_INT8]
converter.inference_input_type  = tf.int8
converter.inference_output_type = tf.int8

tflite_model = converter.convert()

with open("trained.tflite", "wb") as f:
    f.write(tflite_model)

print(f"TFLite model size: {len(tflite_model) / 1024:.1f} KB")
# Out:
# INFO:tensorflow:Assets written to: /tmp/tmpu27dnl9q/assets
# INFO:tensorflow:Assets written to: /tmp/tmpu27dnl9q/assets
# Saved artifact at '/tmp/tmpu27dnl9q'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 96, 96, 3), dtype=tf.float32, name='keras_tensor_2')
# Output Type:
#   TensorSpec(shape=(None, 2), dtype=tf.float32, name=None)
# Captures:
#   133500335441872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500335442832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500335446672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500335443024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500335446288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500335444560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500335444176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500335444368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500335444944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500335443216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500335442064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500347623632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500347623824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500347622096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500347622288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500347624208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500347618832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500347613456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500347620176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500347624400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500347613648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500336230224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500336230800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500336230992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500336231568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500336233104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500336233488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500336233872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500336233680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500336230416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500336235024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500336235408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500336235792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500336235600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500336231952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500336236944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500336237328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500336237712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500336237520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500336232720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500336234640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500336239440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500336239824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500336239632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500336236176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500336238480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500336241552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500336242320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500336241744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500336238864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500336240976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500266955408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500266955984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500336241168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500266955024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500266957136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500266957520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500266957904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500266957712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500266954832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500266959056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500266959440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500266959824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500266959632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500266955600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500266960976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500266961360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500266961744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500266961552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500266956752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500266962896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500266963280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500266963664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500266963472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500266958672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500266964816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500266965200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500266965584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500266965392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500266960592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500266966736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500266967120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500266967504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500266967312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500266962512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500266968656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500266969040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500266969424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500266969232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500266964432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500266970576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500266955216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500266970960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500266970768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500266968272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500140356048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500140357392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500140357776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500140357584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500140356240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500140358928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500140359312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500140359696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500140359504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500140356816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500140360848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500140361232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500140361616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500140361424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500140357008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500140362768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500140363152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500140363536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500140363344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500140358544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500140364688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500140365072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500140365456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500140365264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500140360464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500140366608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500140366992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500140367376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500140367184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500140362384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500140368528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500140368912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500140369296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500140369104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500140364304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500140370448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500140370832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500140371600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500140371024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500140366224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500140369680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500140700304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500140700880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500140370064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500140699920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500140702032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500140702416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500140702800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500140702608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500140699728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500140703952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500140704336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500140704720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500140704528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500140700496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500140705872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500140706256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500140706640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500140706448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500140701648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500140707792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500140708176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500140708560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500140708368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500140703568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500140709712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500140710096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500140710480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500140710288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500140705488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500140711632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500140712016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500140712400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500140712208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500140707408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500140713552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500140713936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500140714320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500140714128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500140709328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500140715472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500140700112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500140715856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500140715664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500140713168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500136064400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500136064784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500136065168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500136064976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500136063248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500136066320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500136066704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500136067088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500136066896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500136063056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500136068240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500136068624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500136069008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500136068816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500136063824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500136070160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500136070544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500136070928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500136070736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500136065936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500136072080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500136072464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500136072848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500136072656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500136067856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500136074000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500136074384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500136074768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500136074576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500136069776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500136075920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500136076304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500136076688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500136076496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500136071696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500136077840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500136078224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500136078992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500136078416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500136073616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500136077072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500136506384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500136505424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500136077456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500136505616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500136507728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500136508112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500136508496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500136508304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500136505808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500136509648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500136510032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500136510416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500136510224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500136506192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500136511568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500136511952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500136512336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500136512144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500136507344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500136513488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500136513872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500136514256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500136514064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500136509264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500136515408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500136515792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500136516176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500136515984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500136511184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500136517328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500136517712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500136518096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500136517904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500136513104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500136519248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500136519632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500136520016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500136519824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500136515024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500136518864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500135130128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500136521552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500136506576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500135129168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133500135131856: TensorSpec(shape=(), dtype=tf.resource, name=None)
# /usr/local/lib/python3.12/dist-packages/tensorflow/lite/python/convert.py:854: UserWarning: Statistics for quantized inputs were expected, but not specified; continuing anyway.
#   warnings.warn(
# W0000 00:00:1772291206.714049      55 tf_tfl_flatbuffer_helpers.cc:365] Ignored output_format.
# W0000 00:00:1772291206.714087      55 tf_tfl_flatbuffer_helpers.cc:368] Ignored drop_control_dependency.
# I0000 00:00:1772291206.862191      55 mlir_graph_optimization_pass.cc:425] MLIR V1 optimization pass is not enabled
# TFLite model size: 944.9 KB
# fully_quantize: 0, inference_type: 6, input_inference_type: INT8, output_inference_type: INT8

# %% [markdown]
# ## 11. Verify Model Loads (Sanity Check)

# %%
import tensorflow as tf

interpreter = tf.lite.Interpreter(model_content=tflite_model)
interpreter.allocate_tensors()

input_details  = interpreter.get_input_details()
output_details = interpreter.get_output_details()

print("Input:",  input_details[0]["shape"],  "dtype:", input_details[0]["dtype"])
print("Output:", output_details[0]["shape"], "dtype:", output_details[0]["dtype"])

# Tensor arena estimate
details = interpreter.get_tensor_details()
total = sum(
    abs(np.prod(t["shape"])) * np.dtype(t["dtype"]).itemsize
    for t in details
)
print(f"Estimated tensor arena: {total / 1024:.1f} KB")
print(f"File size: {os.path.getsize('trained.tflite') / 1024:.1f} KB")
print("allocate_tensors() passed — model should load on OpenMV")
# Out:
# Input: [ 1 96 96  3] dtype: <class 'numpy.int8'>
# Output: [1 2] dtype: <class 'numpy.int8'>
# Estimated tensor arena: 1395.0 KB
# File size: 944.9 KB
# allocate_tensors() passed — model should load on OpenMV
# /usr/local/lib/python3.12/dist-packages/tensorflow/lite/python/interpreter.py:457: UserWarning:     Warning: tf.lite.Interpreter is deprecated and is scheduled for deletion in
#     TF 2.20. Please use the LiteRT interpreter from the ai_edge_litert package.
#     See the [migration guide](https://ai.google.dev/edge/litert/migration)
#     for details.
#
#   warnings.warn(_INTERPRETER_DELETION_WARNING)
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.

# %% [markdown]
# ## 12. Generate labels.txt
#
# Required alongside `trained.tflite` on the OpenMV drive.

# %%
with open("labels.txt", "w") as f:
    f.write("\n".join(LABELS))

print("labels.txt contents:")
print(open("labels.txt").read())
# Out:
# labels.txt contents:
# not_pcb
# pcb

# %% [markdown]
# ## 13. Download Files
#
# Copy `trained.tflite` and `labels.txt` to your OpenMV drive.

# %%
print("Files ready to download:")
for fname in ["trained.tflite", "labels.txt"]:
    size = os.path.getsize(fname)
    print(f"  {fname}: {size / 1024:.1f} KB")

# files.download("trained.tflite")
# files.download("labels.txt")
# Out:
# Files ready to download:
#   trained.tflite: 944.9 KB
#   labels.txt: 0.0 KB
